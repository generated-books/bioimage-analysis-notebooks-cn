# %% [markdown]
# # Translating a Jupyter book about Bio-image Analsis
# In this notebook we will translate an existing Jupyter book about Bio-image Analsis from English to another language using a large language model. We use Claude 3.5 Sonnet.

# %%
import anthropic
import openai
import datetime
import os
from pathlib import Path
from functools import partial
from IPython.display import Markdown, display
import json
import shutil

openai.__version__, anthropic.__version__
# Out:
# ('1.30.1', '0.29.0')

# %% [markdown]
# ## Defining the content of the book
# First we specify the source content of the book and the target language.

# %%
source_dir = "../BioImageAnalysisNotebooks/"

# %%
target_language = "Chinese"

# %% [markdown]
# We will also specify the location where to store the book:

# %%
base_dir = ""
repository_url = "https://github.com/generated-books/bio-bildanalyse-notebooks"

# %% [markdown]
# We will use this language model to generate the book:

# %%
model = "claude-3-5-sonnet-20240620"

# %% [markdown]
# ## Helper functions
# Here we create some helper functions for prompting and for file format handling.

# %%
def prompt_chatGPT(message:str, model="gpt-4o-2024-05-13"):
    """
    A prompt helper function that sends a message to openAI
    and returns only the text response.
    """
    import os
    import openai
    
    # convert message in the right format if necessary
    if isinstance(message, str):
        message = [{"role": "user", "content": message}]
        
    # setup connection to the LLM
    client = openai.OpenAI()
    
    # submit prompt
    response = client.chat.completions.create(
        model=model,
        messages=message
    )
    
    # extract answer
    return response.choices[0].message.content

# %%
def prompt_claude(message:str, model="claude-3-5-sonnet-20240620"):
    """
    A prompt helper function that sends a message to anthropic
    and returns only the text response.

    Example models: claude-3-5-sonnet-20240620 or claude-3-opus-20240229
    """
    import os
    from anthropic import Anthropic
    
    # convert message in the right format if necessary
    if isinstance(message, str):
        message = [{"role": "user", "content": message}]
        
    # setup connection to the LLM
    client = Anthropic()
    
    message = client.messages.create(
        max_tokens=4096,
        messages=message,
        model=model,
    )

    # extract answer
    return message.content[0].text

# %%
if "gpt" in model:
    prompt = partial(prompt_gpt, model=model)
else:
    prompt = partial(prompt_claude, model=model)

# %%
def prompt_with_memory(message:str):
    """
    This function allows to use an LLMs in a chat-mode. 
    The LLM is equipped with some memory, 
    so that we can refer back for former conversation steps.
    """
    
    # convert message in the right format and store it in memory
    question = {"role": "user", "content": message}
    chat_history.append(question)
    
    # receive answer
    response = prompt(chat_history)
    
    # convert answer in the right format and store it in memory
    answer = {"role": "assistant", "content": response}
    chat_history.append(answer)
    
    return response

# %%
def is_valid_json(test_string):
    """This function returns if a string is formatted json."""
    import json
    try:
        json.loads(test_string)
        return True
    except:
        return False

def ensure_json(notebook):
    """This function makes sure that the passed notebook is indeed a json-formatted ipynb file."""
    if is_valid_json(notebook):
        return notebook
        
    return prompt(f"""
Take the following text and extract the Jupyter 
notebook ipynb/json from it:

{notebook}

Make sure the output is in ipynb/json format. 
Respond only the JSON content.
""").strip("```json").strip("```python").strip("```")

# %% [markdown]
# ## Context
# Here we provide some context to the language model. As gpt4 and claude have different APIs for providing system messages, we instead use this message to start the conversation.

# %%
system_message = f"""
You are going to translate text from English to {target_language}. 
Do not modify any Python code. Do not translate it. Also do not translate strings in Python code.
In case you receive markdown files or Jupyter notebooks in JSON format, leave the structure of the document as it is and just translate the English text to {target_language}.

Confirm this with "ok".
"""

chat_history = [{"role": "user", "content": system_message}, {"role": "assistant", "content": "ok"}]

# %% [markdown]
# ## Generating the book
# Here we start generating the notebooks for the content listed in the table of contents.

# %%
def translate_file(source_filename, target_filename):
    # remove outputs from jupyter notebooks (because it might be too big otherwise)
    if source_filename.endswith(".ipynb"): # notebook
        # Load the notebook as a JSON object
        with open(source_filename, 'r', encoding='utf-8') as f:
            notebook_content = json.load(f)
    
        # Iterate through the cells and erase the outputs
        for cell in notebook_content['cells']:
            if cell['cell_type'] == 'code':
                cell['outputs'] = []
                cell['execution_count'] = None
    
        file_content = json.dumps(notebook_content, indent=1)
    else:
        with open(source_filename, 'r', encoding='utf-8') as f:
            file_content = f.read()

    # run LLM translation
    translated_content = prompt_with_memory(file_content).strip("'").strip('"')

    # copy code outputs from source to target file
    if source_filename.endswith(".ipynb"): # notebook
        with open(source_filename, 'r', encoding='utf-8') as f:
            notebook_content = json.load(f)
        
        #print(translated_content)
        
        old_content = notebook_content
        new_content = json.loads(translated_content)
    
        for o, n in zip(old_content['cells'], new_content['cells']):
            if "outputs" in o.keys():
                n['outputs'] = o['outputs']
                n['execution_count'] = o['execution_count']
    
        translated_str = json.dumps(new_content, indent=1)
    else:
        translated_str = translated_content

    # save result to target file
    with open(target_filename, 'w', encoding='utf-8') as file:
        file.write(translated_str)

# %%
memory_len = len(chat_history)
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if not "-checkpoint" in file and not "Untitled" in file and not "_build" in root and not ".git/" in root and not ".git\\" in root and not "generator.ipynb" in file:

            source_file = os.path.join(root, file).replace("\\", "/")
            target_file = source_file.replace(source_dir, base_dir).replace("\\", "/")

            # make sure target folder exists
            directory = Path(target_file).parent
            os.makedirs(directory, exist_ok=True)

            if not os.path.exists(target_file): # avoid re-generating the same files
                try:
                    if file.endswith(".md") or file.endswith(".ipynb"):
                        
                        chat_history = chat_history[:memory_len]
                        
                        print(f"Translating {source_file} to {target_file}")
                        translate_file(source_file, target_file)
                    else:
                        print(f"Copying {source_file} to {target_file}")
                        shutil.copy(source_file, target_file)
                except:
                    print("Error")
# Out:
# Copying ../BioImageAnalysisNotebooks/.gitignore to .gitignore
# Copying ../BioImageAnalysisNotebooks/build.sh to build.sh
# Copying ../BioImageAnalysisNotebooks/clean.sh to clean.sh
# Translating ../BioImageAnalysisNotebooks/CODE-OF-CONDUCT.md to CODE-OF-CONDUCT.md
# Translating ../BioImageAnalysisNotebooks/CONTRIBUTING.md to CONTRIBUTING.md
# Copying ../BioImageAnalysisNotebooks/LICENSE-BSD3 to LICENSE-BSD3
# Copying ../BioImageAnalysisNotebooks/LICENSE-CC-BY to LICENSE-CC-BY
# Translating ../BioImageAnalysisNotebooks/readme.md to readme.md
# Copying ../BioImageAnalysisNotebooks/requirements.txt to requirements.txt
# Copying ../BioImageAnalysisNotebooks/.git/COMMIT_EDITMSG to .git/COMMIT_EDITMSG
# Copying ../BioImageAnalysisNotebooks/.git/config to .git/config
# Copying ../BioImageAnalysisNotebooks/.git/description to .git/description
# Copying ../BioImageAnalysisNotebooks/.git/FETCH_HEAD to .git/FETCH_HEAD
# Copying ../BioImageAnalysisNotebooks/.git/HEAD to .git/HEAD
# Copying ../BioImageAnalysisNotebooks/.git/index to .git/index
# Copying ../BioImageAnalysisNotebooks/.git/packed-refs to .git/packed-refs
# Copying ../BioImageAnalysisNotebooks/.github/workflows/book.yml to .github/workflows/book.yml
# Copying ../BioImageAnalysisNotebooks/data/banana0020.tif to data/banana0020.tif
# Copying ../BioImageAnalysisNotebooks/data/banana_source.txt to data/banana_source.txt
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_20P1_POS0007_D_1UL.csv to data/BBBC007_20P1_POS0007_D_1UL.csv
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_20P1_POS0010_D_1UL.csv to data/BBBC007_20P1_POS0010_D_1UL.csv
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_analysis.csv to data/BBBC007_analysis.csv
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_data_source.txt to data/BBBC007_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/BBBC022_image_data_source.txt to data/BBBC022_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/Bead_Image1_crop.tif to data/Bead_Image1_crop.tif
# Copying ../BioImageAnalysisNotebooks/data/binary_arm.tif to data/binary_arm.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs.tif to data/blobs.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_annotated.tif to data/blobs_annotated.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_annotations.tif to data/blobs_annotations.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_classifier.cl to data/blobs_classifier.cl
# Copying ../BioImageAnalysisNotebooks/data/blobs_labeled.tif to data/blobs_labeled.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_object_classifier.cl to data/blobs_object_classifier.cl
# Copying ../BioImageAnalysisNotebooks/data/blobs_object_segmenter.cl to data/blobs_object_segmenter.cl
# Copying ../BioImageAnalysisNotebooks/data/blobs_otsu.tif to data/blobs_otsu.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_otsu_watershed.tif to data/blobs_otsu_watershed.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_sparse_labels.tif to data/blobs_sparse_labels.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_statistics.csv to data/blobs_statistics.csv
# Copying ../BioImageAnalysisNotebooks/data/blobs_stitching1_overlap40.tif to data/blobs_stitching1_overlap40.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_stitching2_overlap40.tif to data/blobs_stitching2_overlap40.tif
# Copying ../BioImageAnalysisNotebooks/data/BMP4blastocystC3-cropped_resampled_8bit.tif to data/BMP4blastocystC3-cropped_resampled_8bit.tif
# Copying ../BioImageAnalysisNotebooks/data/BMP4blastocystC3-cropped_resampled_8bit_image_data_source.txt to data/BMP4blastocystC3-cropped_resampled_8bit_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/BPAE_actin.tif to data/BPAE_actin.tif
# Copying ../BioImageAnalysisNotebooks/data/BPAE_mito.tif to data/BPAE_mito.tif
# Copying ../BioImageAnalysisNotebooks/data/BPAE_nuclei.tif to data/BPAE_nuclei.tif
# Copying ../BioImageAnalysisNotebooks/data/branchoid.ply to data/branchoid.ply
# Copying ../BioImageAnalysisNotebooks/data/CalibZAPWfixed_000154_max.tif to data/CalibZAPWfixed_000154_max.tif
# Copying ../BioImageAnalysisNotebooks/data/cancer_cell_migration_crop.tif to data/cancer_cell_migration_crop.tif
# Translating ../BioImageAnalysisNotebooks/data/cancer_cell_migration_source.md to data/cancer_cell_migration_source.md
# Copying ../BioImageAnalysisNotebooks/data/cancer_cell_migration_voronoi_otsu_labeling_crop.tif to data/cancer_cell_migration_voronoi_otsu_labeling_crop.tif
# Copying ../BioImageAnalysisNotebooks/data/cells3d_annotations.csv to data/cells3d_annotations.csv
# Copying ../BioImageAnalysisNotebooks/data/cells3d_image_source.txt to data/cells3d_image_source.txt
# Copying ../BioImageAnalysisNotebooks/data/cells3d_membranes.tif to data/cells3d_membranes.tif
# Copying ../BioImageAnalysisNotebooks/data/cells3d_nuclei.tif to data/cells3d_nuclei.tif
# Copying ../BioImageAnalysisNotebooks/data/cells_annotation.tif to data/cells_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/DeconvolutionSampleVerticalGrid1AU-crop.tif to data/DeconvolutionSampleVerticalGrid1AU-crop.tif
# Copying ../BioImageAnalysisNotebooks/data/drugs.csv to data/drugs.csv
# Copying ../BioImageAnalysisNotebooks/data/E39.lif [E4] - 2.png to data/E39.lif [E4] - 2.png
# Copying ../BioImageAnalysisNotebooks/data/E39.lif [E4] - 2_image_data_source.txt to data/E39.lif [E4] - 2_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/embryos_grey.tif to data/embryos_grey.tif
# Copying ../BioImageAnalysisNotebooks/data/EM_C_6_c0-1.tif-image data source.txt to data/EM_C_6_c0-1.tif-image data source.txt
# Copying ../BioImageAnalysisNotebooks/data/EM_C_6_c0.ome.tif to data/EM_C_6_c0.ome.tif
# Copying ../BioImageAnalysisNotebooks/data/EM_C_6_c0.tif to data/EM_C_6_c0.tif
# Copying ../BioImageAnalysisNotebooks/data/experiments.csv to data/experiments.csv
# Copying ../BioImageAnalysisNotebooks/data/Haase_MRT_tfl3d1.tif to data/Haase_MRT_tfl3d1.tif
# Copying ../BioImageAnalysisNotebooks/data/hela-cells-8bit.tif to data/hela-cells-8bit.tif
# Copying ../BioImageAnalysisNotebooks/data/hela-cells.tif to data/hela-cells.tif
# Copying ../BioImageAnalysisNotebooks/data/images.csv to data/images.csv
# Copying ../BioImageAnalysisNotebooks/data/label_annotation.tif to data/label_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/label_map_with_index_gaps.tif to data/label_map_with_index_gaps.tif
# Copying ../BioImageAnalysisNotebooks/data/Lund-25MB.tif to data/Lund-25MB.tif
# Copying ../BioImageAnalysisNotebooks/data/Lund_000500_resampled-cropped.tif to data/Lund_000500_resampled-cropped.tif
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm.model.cl to data/maize_clsm.model.cl
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm.tif to data/maize_clsm.tif
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm_annotation.tif to data/maize_clsm_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm_labels.tif to data/maize_clsm_labels.tif
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm_source.txt to data/maize_clsm_source.txt
# Copying ../BioImageAnalysisNotebooks/data/maize_cslm_object_classifier.cl to data/maize_cslm_object_classifier.cl
# Copying ../BioImageAnalysisNotebooks/data/measurements.csv to data/measurements.csv
# Copying ../BioImageAnalysisNotebooks/data/membrane2d.tif to data/membrane2d.tif
# Copying ../BioImageAnalysisNotebooks/data/membrane2d_merge_annotation.tif to data/membrane2d_merge_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/membrane2d_oversegmented.tif to data/membrane2d_oversegmented.tif
# Copying ../BioImageAnalysisNotebooks/data/membranes_2d.tif to data/membranes_2d.tif
# Copying ../BioImageAnalysisNotebooks/data/membranes_2d_sparse_labels.tif to data/membranes_2d_sparse_labels.tif
# Copying ../BioImageAnalysisNotebooks/data/membrane_2d_timelapse.tif to data/membrane_2d_timelapse.tif
# Copying ../BioImageAnalysisNotebooks/data/membrane_2d_timelapse_image_data_source.txt to data/membrane_2d_timelapse_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/mitosis.tif to data/mitosis.tif
# Copying ../BioImageAnalysisNotebooks/data/mitosis_mod.tif to data/mitosis_mod.tif
# Copying ../BioImageAnalysisNotebooks/data/mri_fruit_bvtkn4mm_source.txt to data/mri_fruit_bvtkn4mm_source.txt
# Copying ../BioImageAnalysisNotebooks/data/mri_fruit_bvtnk4mm.jpg to data/mri_fruit_bvtnk4mm.jpg
# Copying ../BioImageAnalysisNotebooks/data/mri_fruit_sxm89b3x.jpg to data/mri_fruit_sxm89b3x.jpg
# Copying ../BioImageAnalysisNotebooks/data/mri_fruit_sxm89b3x_source.txt to data/mri_fruit_sxm89b3x_source.txt
# Copying ../BioImageAnalysisNotebooks/data/Multi_analysis.csv to data/Multi_analysis.csv
# Copying ../BioImageAnalysisNotebooks/data/nuclei.tif to data/nuclei.tif
# Copying ../BioImageAnalysisNotebooks/data/overview.csv to data/overview.csv
# Copying ../BioImageAnalysisNotebooks/data/P1_H_C3H_M004_17-cropped-license.txt to data/P1_H_C3H_M004_17-cropped-license.txt
# Copying ../BioImageAnalysisNotebooks/data/P1_H_C3H_M004_17-cropped.tif to data/P1_H_C3H_M004_17-cropped.tif
# Copying ../BioImageAnalysisNotebooks/data/plate1_1_013 [Well 5, Field 1 (Spot 5)].png to data/plate1_1_013 [Well 5, Field 1 (Spot 5)].png
# Copying ../BioImageAnalysisNotebooks/data/plate1_1_013 [Well 5, Field 1 (Spot 5)]_image_data_source.txt to data/plate1_1_013 [Well 5, Field 1 (Spot 5)]_image_data_source.txt
# Translating ../BioImageAnalysisNotebooks/data/Platynereis_source.md to data/Platynereis_source.md
# Copying ../BioImageAnalysisNotebooks/data/Platynereis_tp7_channel1_rescaled(256x256x103)_gt.tif to data/Platynereis_tp7_channel1_rescaled(256x256x103)_gt.tif
# Copying ../BioImageAnalysisNotebooks/data/Platynereis_tp7_channel1_rescaled(256x256x103)_voronoi_otsu_label_image.tif to data/Platynereis_tp7_channel1_rescaled(256x256x103)_voronoi_otsu_label_image.tif
# Copying ../BioImageAnalysisNotebooks/data/psf.tif to data/psf.tif
# Copying ../BioImageAnalysisNotebooks/data/PupalWing.czi to data/PupalWing.czi
# Copying ../BioImageAnalysisNotebooks/data/PupalWing_image_data_source.txt to data/PupalWing_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/real_cat.png to data/real_cat.png
# Copying ../BioImageAnalysisNotebooks/data/real_cat_mic_mask.tif to data/real_cat_mic_mask.tif
# Copying ../BioImageAnalysisNotebooks/data/reference_labels.tif to data/reference_labels.tif
# Copying ../BioImageAnalysisNotebooks/data/Results.csv to data/Results.csv
# Copying ../BioImageAnalysisNotebooks/data/rounding_assay.tif to data/rounding_assay.tif
# Copying ../BioImageAnalysisNotebooks/data/rounding_assay_source.txt to data/rounding_assay_source.txt
# Copying ../BioImageAnalysisNotebooks/data/short_table.csv to data/short_table.csv
# Copying ../BioImageAnalysisNotebooks/data/syntetic_cells.tif to data/syntetic_cells.tif
# Copying ../BioImageAnalysisNotebooks/data/syntetic_cells_merge_annotation.tif to data/syntetic_cells_merge_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/zfish_eye.tif to data/zfish_eye.tif
# Copying ../BioImageAnalysisNotebooks/data/zfish_eye_source.txt to data/zfish_eye_source.txt
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0002.tif to data/banana/banana0002.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0003.tif to data/banana/banana0003.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0004.tif to data/banana/banana0004.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0005.tif to data/banana/banana0005.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0006.tif to data/banana/banana0006.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0007.tif to data/banana/banana0007.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0008.tif to data/banana/banana0008.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0009.tif to data/banana/banana0009.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0010.tif to data/banana/banana0010.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0011.tif to data/banana/banana0011.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0012.tif to data/banana/banana0012.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0013.tif to data/banana/banana0013.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0014.tif to data/banana/banana0014.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0015.tif to data/banana/banana0015.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0016.tif to data/banana/banana0016.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0017.tif to data/banana/banana0017.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0018.tif to data/banana/banana0018.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0019.tif to data/banana/banana0019.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0020.tif to data/banana/banana0020.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0021.tif to data/banana/banana0021.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0022.tif to data/banana/banana0022.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0023.tif to data/banana/banana0023.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0024.tif to data/banana/banana0024.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0025.tif to data/banana/banana0025.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0026.tif to data/banana/banana0026.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/image_source.txt to data/banana/image_source.txt
# Translating ../BioImageAnalysisNotebooks/data/BBBC007/readme.md to data/BBBC007/readme.md
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/images/A9 p5d (cropped 1).tif to data/BBBC007/images/A9 p5d (cropped 1).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/images/A9 p5d (cropped 2).tif to data/BBBC007/images/A9 p5d (cropped 2).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/images/A9 p5d (cropped 3).tif to data/BBBC007/images/A9 p5d (cropped 3).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/images/A9 p5d (cropped 4).tif to data/BBBC007/images/A9 p5d (cropped 4).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/masks/A9 p5d (cropped 1).tif to data/BBBC007/masks/A9 p5d (cropped 1).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/masks/A9 p5d (cropped 2).tif to data/BBBC007/masks/A9 p5d (cropped 2).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/masks/A9 p5d (cropped 3).tif to data/BBBC007/masks/A9 p5d (cropped 3).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/masks/A9 p5d (cropped 4).tif to data/BBBC007/masks/A9 p5d (cropped 4).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/17P1_POS0013_D_1UL.tif to data/BBBC007_batch/17P1_POS0013_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/20P1_POS0005_D_1UL.tif to data/BBBC007_batch/20P1_POS0005_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/20P1_POS0007_D_1UL.tif to data/BBBC007_batch/20P1_POS0007_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/20P1_POS0010_D_1UL.tif to data/BBBC007_batch/20P1_POS0010_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/A9 p7d.tif to data/BBBC007_batch/A9 p7d.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/AS_09125_040701150004_A02f00d0.tif to data/BBBC007_batch/AS_09125_040701150004_A02f00d0.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/17P1_POS0013_D_1UL.tif to data/BBBC007_sparse_instance_annotation/17P1_POS0013_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/20P1_POS0005_D_1UL.tif to data/BBBC007_sparse_instance_annotation/20P1_POS0005_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/20P1_POS0007_D_1UL.tif to data/BBBC007_sparse_instance_annotation/20P1_POS0007_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/20P1_POS0010_D_1UL.tif to data/BBBC007_sparse_instance_annotation/20P1_POS0010_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/A9 p7d.tif to data/BBBC007_sparse_instance_annotation/A9 p7d.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/AS_09125_040701150004_A02f00d0.tif to data/BBBC007_sparse_instance_annotation/AS_09125_040701150004_A02f00d0.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC022/IXMtest_A02_s9.tif to data/BBBC022/IXMtest_A02_s9.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC022/IXMtest_A02_s9_image_data_source.txt to data/BBBC022/IXMtest_A02_s9_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/BBBC038/0bf4b1.tif to data/BBBC038/0bf4b1.tif
# Translating ../BioImageAnalysisNotebooks/docs/imprint.md to docs/imprint.md
# Translating ../BioImageAnalysisNotebooks/docs/intro.md to docs/intro.md
# Copying ../BioImageAnalysisNotebooks/docs/logo.png to docs/logo.png
# Copying ../BioImageAnalysisNotebooks/docs/references.bib to docs/references.bib
# Copying ../BioImageAnalysisNotebooks/docs/requirements.txt to docs/requirements.txt
# Copying ../BioImageAnalysisNotebooks/docs/_config.yml to docs/_config.yml
# Copying ../BioImageAnalysisNotebooks/docs/_toc.yml to docs/_toc.yml
# Translating ../BioImageAnalysisNotebooks/docs/01_introduction/glossary.md to docs/01_introduction/glossary.md
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/hello_world.png to docs/01_introduction/hello_world.png
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/install_jupyter.png to docs/01_introduction/install_jupyter.png
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/install_mambaforge.png to docs/01_introduction/install_mambaforge.png
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/install_mambaforge2.png to docs/01_introduction/install_mambaforge2.png
# Translating ../BioImageAnalysisNotebooks/docs/01_introduction/readme.md to docs/01_introduction/readme.md
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/start_jupyter_lab.png to docs/01_introduction/start_jupyter_lab.png
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/test_opencl.png to docs/01_introduction/test_opencl.png
# Translating ../BioImageAnalysisNotebooks/docs/01_introduction/trailer.ipynb to docs/01_introduction/trailer.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/01_our_first_juptyer_notebook.ipynb to docs/02_python_basics/01_our_first_juptyer_notebook.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/02_Math_in_python.ipynb to docs/02_python_basics/02_Math_in_python.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/03_Dont_try_this_at_home.ipynb to docs/02_python_basics/03_Dont_try_this_at_home.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/04_Basic_types.ipynb to docs/02_python_basics/04_Basic_types.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/05a_cropping_lists.ipynb to docs/02_python_basics/05a_cropping_lists.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/05b_sorting_lists.ipynb to docs/02_python_basics/05b_sorting_lists.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/05_lists_tuples.ipynb to docs/02_python_basics/05_lists_tuples.ipynb
